# %% [markdown]
# ## Breast Cancer Dataset

# %%
import pandas as pd #data processing, CSV file I/O (e.g. pd.read_csv)

import numpy as np # linear algebra

import matplotlib.pyplot as plt #data visualization library
# %matplotlib inline

import seaborn as sns #data visualization library based on matplotlib

# %%
bc=pd.read_csv("breast_cancer_detection.csv") #Reading the csv file

# %%
bc.head() #Reading the data i.e. the first 5 rows
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
bc.tail()  #Reading the data i.e. the last 5 rows
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
bc.size #Size of the data i.e. 18,777 entries
# Out:
# 18777

# %%
bc.shape #Shape of data i.e. 569 instances and 33 features
# Out:
# (569, 33)

# %%
bc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ## After getting the information of the data , we can see that there are 569 instances and 33 features
# ## there are no null values i.e. no missing values
# ## There are 31 features containing data type float , 1 feature containing data type integer ('id') and 1 feature containing data type object ('diagnosis')

# %%
bc.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ## Dropping the Columns which are not that useful

# %%
bc.drop(['Unnamed: 32','id'],axis=1,inplace=True)

# %%
bc.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(20,18))
sns.heatmap(bc.corr(),annot=True);

# %%
bc.hist(bins=20,figsize=(13,15));

# %% [markdown]
# ## Finding the unique values

# %%
bc.nunique()
# Out:
# diagnosis                    2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# concave points_mean        542
# symmetry_mean              432
# fractal_dimension_mean     499
# radius_se                  540
# texture_se                 519
# perimeter_se               533
# area_se                    528
# smoothness_se              547
# compactness_se             541
# concavity_se               533
# concave points_se          507
# symmetry_se                498
# fractal_dimension_se       545
# radius_worst               457
# texture_worst              511
# perimeter_worst            514
# area_worst                 544
# smoothness_worst           411
# compactness_worst          529
# concavity_worst            539
# concave points_worst       492
# symmetry_worst             500
# ...

# %% [markdown]
# ## Handling the missing values

# %%
bc.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ## Handling The Outliers

# %%
for colname,colvals in bc.iteritems():
    if bc[colname].dtype!=object and colname!='diagnosis':
        Q1=bc[colname].quantile(q=0.25)
        Q3=bc[colname].quantile(q=0.75)
        IQR=Q3-Q1
        low=Q1-(1.5*IQR)
        up=Q3+(1.5*IQR)
        bc.loc[(bc[colname]<=low) | (bc[colname]>=up) ,colname]
        print(colname)
    else:
        continue
# Out:
# radius_mean
# texture_mean
# perimeter_mean
# area_mean
# smoothness_mean
# compactness_mean
# concavity_mean
# concave points_mean
# symmetry_mean
# fractal_dimension_mean
# radius_se
# texture_se
# perimeter_se
# area_se
# smoothness_se
# compactness_se
# concavity_se
# concave points_se
# symmetry_se
# fractal_dimension_se
# radius_worst
# texture_worst
# perimeter_worst
# area_worst
# smoothness_worst
# compactness_worst
# concavity_worst
# concave points_worst
# symmetry_worst
# fractal_dimension_worst

# %%
for colname,colvals in bc.iteritems():
    if bc[colname].dtype!=object and colname!='diagnosis':
        Q1=bc[colname].quantile(q=0.25)
        Q3=bc[colname].quantile(q=0.75)
        IQR=Q3-Q1
        low=Q1-(1.5*IQR)
        up=Q3+(1.5*IQR)
        bc.loc[(bc[colname]<low) | (bc[colname]>up) ,colname]=bc[colname].median()
    else:
        continue

# %% [markdown]
# ## Handling the categorical data

# %%
bc=pd.get_dummies(bc,drop_first=True)

# %%
bc.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.09587
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.09263         0.06154              0.14710         0.2419
# 1           0.07864         0.08690              0.07017         0.1812
# 2           0.15990         0.19740              0.12790         0.2069
# 3           0.09263         0.24140              0.10520         0.1792
# 4           0.13280         0.19800              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %% [markdown]
# ## Machine Learning Algorithm

# %%
# select x & y
# x=independent columns
# y=Dependent columns(Traget columns)
X=bc.drop('diagnosis_M',axis=1)
y=bc['diagnosis_M']

# %%
# stadardization
# To comes all Data into one unit excpet Traget columns.Data comes in between(0,1)
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
# split the data in traininig and Testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=42)

# %%
# model selation
# import the model
# Dataset Target columns is Binary hence we go for LogisticRegression 
from sklearn.linear_model import LogisticRegression
 
# instantiate the model
logreg=LogisticRegression()

# fit the model with Training Data
logreg.fit(x_train,y_train)

# prediction of Data
y_train_pred=logreg.predict(x_train)
y_test_pred=logreg.predict(x_test)

# %%
from sklearn import metrics
print("Training Accuracy:",metrics.accuracy_score(y_train,y_train_pred))
print("Testing Accuracy:",metrics.accuracy_score(y_test,y_test_pred))
# Out:
# Training Accuracy: 0.9692307692307692
# Testing Accuracy: 0.9824561403508771

# %%
# confusion metrix
# Training Data
from sklearn.metrics import confusion_matrix
cnf_metrix_train=confusion_matrix(y_train,y_train_pred)
cnf_metrix_train
# Out:
# array([[282,   4],
#        [ 10, 159]], dtype=int64)

# %%
from sklearn import metrics
print("Training Precision:",metrics.precision_score(y_train,y_train_pred))
print("Testing Precision:",metrics.precision_score(y_test,y_test_pred))
print("Training Recall:",metrics.recall_score(y_train,y_train_pred))
print("Testing Recall:",metrics.recall_score(y_test,y_test_pred))
# Out:
# Training Precision: 0.9754601226993865
# Testing Precision: 0.9767441860465116
# Training Recall: 0.9408284023668639
# Testing Recall: 0.9767441860465116

# %%
Training_result=metrics.classification_report(y_train,y_train_pred)
print(Training_result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       286
#            1       0.98      0.94      0.96       169
#
#     accuracy                           0.97       455
#    macro avg       0.97      0.96      0.97       455
# weighted avg       0.97      0.97      0.97       455

# %%
Testing_result=metrics.classification_report(y_test,y_test_pred)
print(Testing_result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
